# %%
import tensorflow.keras
from tensorflow.keras import layers
from tensorflow.keras import Model 
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.layers import Dense,Conv2D, Flatten, MaxPool2D, Dropout

# %%
import os
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
train_path = (r"C:\Users\amarp\Downloads\Data\train")
val_path = (r"C:\Users\amarp\Downloads\Data\valid")
test_path = (r"C:\Users\amarp\Downloads\Data\test")

# %%
def GetDatasetSize(path):
    num_of_image = {}
    for folder in os.listdir(path):
        # Counting the Number of Files in the Folder
        num_of_image[folder] = len(os.listdir(os.path.join(path, folder)));
    return num_of_image;
    
train_set = GetDatasetSize(train_path)
val_set = GetDatasetSize(val_path)
test_set = GetDatasetSize(test_path)
print(train_set,"\n\n",val_set,"\n\n",test_set)
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 195, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 115, 'normal': 148, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 155}
#
#  {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 23, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 21, 'normal': 13, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 15}
#
#  {'adenocarcinoma': 120, 'large.cell.carcinoma': 51, 'normal': 54, 'squamous.cell.carcinoma': 90}

# %%
labels = ['squamous.cell.carcinoma', 'normal', 'adenocarcinoma', 'large.cell.carcinoma']
train_list = list(train_set.values())
val_list = list(val_set.values())
test_list = list(test_set.values())

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, train_list, width, label='Train')
rects2 = ax.bar(x, val_list, width, label='Val')
rects3 = ax.bar(x + width, test_list, width, label='Test')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Images Count')
ax.set_title('Dataset')
ax.set_xticks(x, labels)
plt.xticks(rotation=15)
ax.legend()

ax.bar_label(rects1)
ax.bar_label(rects2)
ax.bar_label(rects3)

fig.tight_layout()

plt.show()

# %%
train_datagen = ImageDataGenerator(rescale = 1.0/255.0,
                                  horizontal_flip = True,
                                  fill_mode = 'nearest',
                                  zoom_range=0.2,
                                  shear_range = 0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  rotation_range=0.4)

train_data = train_datagen.flow_from_directory(train_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 613 images belonging to 4 classes.

# %%
train_data.class_indices
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
val_datagen = ImageDataGenerator(rescale = 1.0/255.0)
val_data = val_datagen.flow_from_directory(val_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 72 images belonging to 4 classes.

# %%
val_data.class_indices
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
test_datagen = ImageDataGenerator(rescale = 1.0/255.0)
test_data = test_datagen.flow_from_directory(test_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 315 images belonging to 4 classes.

# %%
test_data.class_indices
# Out:
# {'adenocarcinoma': 0,
#  'large.cell.carcinoma': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma': 3}

# %% [markdown]
# # VGG-16

# %%
base_model = VGG16(
    weights='imagenet',
    include_top=False, 
    input_shape=(350,350,3)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 12s 0us/step

# %%
NUM_CLASSES = 4

vgg_model = Sequential()
vgg_model.add(base_model)
vgg_model.add(layers.Flatten())
vgg_model.add(layers.Dropout(0.25))
vgg_model.add(layers.Dense(NUM_CLASSES, activation='sigmoid'))

vgg_model.layers[0].trainable = False

vgg_model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

vgg_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 10, 10, 512)    │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 51200)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 51200)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │       204,804 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,919,492 (56.91 MB)
#  Trainable params: 204,804 (800.02 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
# Adding Model check point Callback

mc = ModelCheckpoint(
    filepath="./ct_vgg_best_model.keras",
    monitor= 'val_accuracy', 
    verbose= 1,
    save_best_only= True, 
    mode = 'auto'
    );

call_back = [ mc];

# %%
# Fitting the Model
vgg = vgg_model.fit(
    train_data, 
    steps_per_epoch = train_data.samples//train_data.batch_size, 
    epochs = 32, 
    validation_data = val_data, 
    validation_steps = val_data.samples//val_data.batch_size,
    callbacks = call_back 
    )
# Out:
# Epoch 1/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.3771 - loss: 2.5790
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to ./ct_vgg_best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 745s 6s/step - accuracy: 0.3777 - loss: 2.5766 - val_accuracy: 0.5000 - val_loss: 1.5431
# Epoch 2/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 12:09 6s/step - accuracy: 0.4000 - loss: 1.3105
# Epoch 2: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.4000 - loss: 1.3105 - val_accuracy: 0.5000 - val_loss: 1.4044
# Epoch 3/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5742 - loss: 1.7290
# Epoch 3: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 731s 6s/step - accuracy: 0.5740 - loss: 1.7301 - val_accuracy: 0.3429 - val_loss: 6.4283
# Epoch 4/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 11:06 6s/step - accuracy: 0.6000 - loss: 3.8887
# Epoch 4: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.6000 - loss: 3.8887 - val_accuracy: 0.5000 - val_loss: 5.0068
# Epoch 5/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5857 - loss: 1.9131
# Epoch 5: val_accuracy improved from 0.50000 to 0.64286, saving model to ./ct_vgg_best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 737s 6s/step - accuracy: 0.5860 - loss: 1.9099 - val_accuracy: 0.6429 - val_loss: 1.2166
# Epoch 6/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 10:34 5s/step - accuracy: 0.8000 - loss: 0.6077
# Epoch 6: val_accuracy improved from 0.64286 to 1.00000, saving model to ./ct_vgg_best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.8000 - loss: 0.6077 - val_accuracy: 1.0000 - val_loss: 0.0203
# Epoch 7/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7072 - loss: 1.0570
# Epoch 7: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 791s 6s/step - accuracy: 0.7068 - loss: 1.0586 - val_accuracy: 0.6286 - val_loss: 1.4032
# Epoch 8/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 10:22 5s/step - accuracy: 0.6000 - loss: 2.8084
# Epoch 8: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6000 - loss: 2.8084 - val_accuracy: 1.0000 - val_loss: 0.0298
# Epoch 9/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7062 - loss: 1.3553
# Epoch 9: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 748s 6s/step - accuracy: 0.7062 - loss: 1.3558 - val_accuracy: 0.7143 - val_loss: 0.9081
# Epoch 10/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 11:01 5s/step - accuracy: 0.6000 - loss: 1.4892
# Epoch 10: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.6000 - loss: 1.4892 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 11/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.6422 - loss: 1.7645
# Epoch 11: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 788s 6s/step - accuracy: 0.6422 - loss: 1.7653 - val_accuracy: 0.6286 - val_loss: 1.4169
# Epoch 12/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 11:22 6s/step - accuracy: 0.2000 - loss: 2.6864
# Epoch 12: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.2000 - loss: 2.6864 - val_accuracy: 0.5000 - val_loss: 2.6613
# Epoch 13/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6747 - loss: 1.5141
# Epoch 13: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 742s 6s/step - accuracy: 0.6749 - loss: 1.5123 - val_accuracy: 0.7286 - val_loss: 0.9787
# Epoch 14/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 10:28 5s/step - accuracy: 0.6000 - loss: 0.8790
# Epoch 14: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - accuracy: 0.6000 - loss: 0.8790 - val_accuracy: 0.5000 - val_loss: 3.0108
# Epoch 15/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8064 - loss: 0.6370
# Epoch 15: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 717s 6s/step - accuracy: 0.8064 - loss: 0.6377 - val_accuracy: 0.7000 - val_loss: 1.6828
# Epoch 16/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 10:22 5s/step - accuracy: 1.0000 - loss: 0.0134
# Epoch 16: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 1.0000 - val_loss: 0.0075
# Epoch 17/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7093 - loss: 1.2832
# Epoch 17: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 718s 6s/step - accuracy: 0.7093 - loss: 1.2828 - val_accuracy: 0.6429 - val_loss: 1.7907
# Epoch 18/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 10:22 5s/step - accuracy: 1.0000 - loss: 0.1561
# Epoch 18: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 1.0000 - loss: 0.1561 - val_accuracy: 1.0000 - val_loss: 0.0099
# Epoch 19/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7395 - loss: 1.1910
# Epoch 19: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 737s 6s/step - accuracy: 0.7390 - loss: 1.1962 - val_accuracy: 0.6571 - val_loss: 2.0024
# Epoch 20/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 10:20 5s/step - accuracy: 0.8000 - loss: 0.3016
# Epoch 20: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8000 - loss: 0.3016 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 21/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7325 - loss: 1.1169
# Epoch 21: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 724s 6s/step - accuracy: 0.7323 - loss: 1.1201 - val_accuracy: 0.7714 - val_loss: 1.1079
# Epoch 22/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 10:18 5s/step - accuracy: 0.6000 - loss: 1.2038
# Epoch 22: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6000 - loss: 1.2038 - val_accuracy: 0.5000 - val_loss: 1.4112
# Epoch 23/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7148 - loss: 1.4348
# Epoch 23: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 717s 6s/step - accuracy: 0.7150 - loss: 1.4325 - val_accuracy: 0.7429 - val_loss: 1.4655
# Epoch 24/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 10:10 5s/step - accuracy: 0.8000 - loss: 1.1477
# Epoch 24: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.8000 - loss: 1.1477 - val_accuracy: 1.0000 - val_loss: 0.0360
# Epoch 25/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7485 - loss: 1.3121
# Epoch 25: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 714s 6s/step - accuracy: 0.7484 - loss: 1.3127 - val_accuracy: 0.4571 - val_loss: 3.7736
# Epoch 26/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 10:21 5s/step - accuracy: 0.6000 - loss: 2.6649
# Epoch 26: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.6000 - loss: 2.6649 - val_accuracy: 0.5000 - val_loss: 2.2958
# Epoch 27/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7487 - loss: 1.1758
# Epoch 27: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 712s 6s/step - accuracy: 0.7485 - loss: 1.1773 - val_accuracy: 0.4286 - val_loss: 4.5209
# Epoch 28/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 10:22 5s/step - accuracy: 0.6000 - loss: 1.4548
# Epoch 28: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.6000 - loss: 1.4548 - val_accuracy: 0.5000 - val_loss: 5.1844
# Epoch 29/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7657 - loss: 1.1295
# Epoch 29: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 741s 6s/step - accuracy: 0.7657 - loss: 1.1291 - val_accuracy: 0.8000 - val_loss: 1.3894
# Epoch 30/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 12:11 6s/step - accuracy: 0.6000 - loss: 1.7688
# Epoch 30: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.6000 - loss: 1.7688 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 31/32
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7485 - loss: 1.2269
# Epoch 31: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 726s 6s/step - accuracy: 0.7486 - loss: 1.2272 - val_accuracy: 0.7857 - val_loss: 0.9478
# Epoch 32/32
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 10:23 5s/step - accuracy: 0.6000 - loss: 0.5722
# Epoch 32: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6000 - loss: 0.5722 - val_accuracy: 0.5000 - val_loss: 5.7019

# %%
# Loading the Best Fit Model 
model = load_model("./ct_vgg_best_model.keras")

# %%
# Checking the Accuracy of the Model 
accuracy_vgg = model.evaluate(test_data)[1] 
print(f"The accuracy of the model is = {accuracy_vgg*100} %")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 357s 6s/step - accuracy: 0.7284 - loss: 0.7986
# The accuracy of the model is = 72.69841432571411 %

# %%
vgg.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Plot model performance
acc = vgg.history['accuracy']
val_acc = vgg.history['val_accuracy']
loss = vgg.history['loss']
val_loss = vgg.history['val_loss']
epochs_range = range(1, len(vgg.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

plt.tight_layout()
plt.show()
