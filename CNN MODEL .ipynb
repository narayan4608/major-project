# %%
import tensorflow.keras
from tensorflow.keras import layers
from tensorflow.keras import Model 
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.layers import Dense,Conv2D, Flatten, MaxPool2D, Dropout

# %%
import os
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
train_path = (r"C:\Users\amarp\Downloads\Data\train")
val_path = (r"C:\Users\amarp\Downloads\Data\valid")
test_path = (r"C:\Users\amarp\Downloads\Data\test")

# %%
def GetDatasetSize(path):
    num_of_image = {}
    for folder in os.listdir(path):
        # Counting the Number of Files in the Folder
        num_of_image[folder] = len(os.listdir(os.path.join(path, folder)));
    return num_of_image;
    
train_set = GetDatasetSize(train_path)
val_set = GetDatasetSize(val_path)
test_set = GetDatasetSize(test_path)
print(train_set,"\n\n",val_set,"\n\n",test_set)
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 195, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 115, 'normal': 148, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 155}
#
#  {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 23, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 21, 'normal': 13, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 15}
#
#  {'adenocarcinoma': 120, 'large.cell.carcinoma': 51, 'normal': 54, 'squamous.cell.carcinoma': 90}

# %%
labels = ['squamous.cell.carcinoma', 'normal', 'adenocarcinoma', 'large.cell.carcinoma']
train_list = list(train_set.values())
val_list = list(val_set.values())
test_list = list(test_set.values())

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, train_list, width, label='Train')
rects2 = ax.bar(x, val_list, width, label='Val')
rects3 = ax.bar(x + width, test_list, width, label='Test')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Images Count')
ax.set_title('Dataset')
ax.set_xticks(x, labels)
plt.xticks(rotation=15)
ax.legend()

ax.bar_label(rects1)
ax.bar_label(rects2)
ax.bar_label(rects3)

fig.tight_layout()

plt.show()

# %%
train_datagen = ImageDataGenerator(rescale = 1.0/255.0,
                                  horizontal_flip = True,
                                  fill_mode = 'nearest',
                                  zoom_range=0.2,
                                  shear_range = 0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  rotation_range=0.4)

train_data = train_datagen.flow_from_directory(train_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 613 images belonging to 4 classes.

# %%
train_data.class_indices
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
val_datagen = ImageDataGenerator(rescale = 1.0/255.0)
val_data = val_datagen.flow_from_directory(val_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 72 images belonging to 4 classes.

# %%
val_data.class_indices
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
test_datagen = ImageDataGenerator(rescale = 1.0/255.0)
test_data = test_datagen.flow_from_directory(test_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 315 images belonging to 4 classes.

# %%
test_data.class_indices
# Out:
# {'adenocarcinoma': 0,
#  'large.cell.carcinoma': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma': 3}

# %% [markdown]
# # CNN MODEL

# %%
model = Sequential() 

# Convolutional Layer with input shape (350,350,3)
model.add(Conv2D(filters=32, kernel_size= (3,3), activation= 'relu', input_shape=(350,350,3)) )

model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu' ))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu' ))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu' ))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Dropout(rate=0.25))

model.add(Flatten())
model.add(Dense(units=64, activation='relu'))
model.add(Dropout(rate=0.25))
model.add(Dense(units=4, activation='sigmoid'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']  )
 
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 348, 348, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 346, 346, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 173, 173, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 171, 171, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 85, 85, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 83, 83, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 41, 41, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 41, 41, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 215168)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │    13,770,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,873,572 (52.92 MB)
#  Trainable params: 13,873,572 (52.92 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Adding Model check point Callback

mc = ModelCheckpoint(
    filepath="./ct_cnn_best_model.keras",
    monitor= 'val_accuracy', 
    verbose= 1,
    save_best_only= True, 
    mode = 'auto'
    );

call_back = [mc];

# %%
# Fitting the Model
cnn = model.fit(
    train_data, 
    steps_per_epoch = train_data.samples//train_data.batch_size, 
    epochs = 20, 
    validation_data = val_data, 
    validation_steps = val_data.samples//val_data.batch_size,
    callbacks = call_back
    )
# Out:
# Epoch 1/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3483 - loss: 1.3715
# Epoch 1: val_accuracy improved from -inf to 0.28571, saving model to ./ct_cnn_best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 265s 2s/step - accuracy: 0.3486 - loss: 1.3708 - val_accuracy: 0.2857 - val_loss: 1.2036
# Epoch 2/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 4:10 2s/step - accuracy: 0.4000 - loss: 1.3188
# Epoch 2: val_accuracy improved from 0.28571 to 0.50000, saving model to ./ct_cnn_best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.4000 - loss: 1.3188 - val_accuracy: 0.5000 - val_loss: 0.6648
# Epoch 3/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4129 - loss: 1.1645
# Epoch 3: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 246s 2s/step - accuracy: 0.4133 - loss: 1.1641 - val_accuracy: 0.5000 - val_loss: 1.0825
# Epoch 4/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 4:01 2s/step - accuracy: 0.8000 - loss: 0.8320
# Epoch 4: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8000 - loss: 0.8320 - val_accuracy: 0.5000 - val_loss: 0.7758
# Epoch 5/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4863 - loss: 1.0440
# Epoch 5: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 257s 2s/step - accuracy: 0.4862 - loss: 1.0440 - val_accuracy: 0.5000 - val_loss: 0.9744
# Epoch 6/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 3:58 2s/step - accuracy: 0.4000 - loss: 1.0684
# Epoch 6: val_accuracy did not improve from 0.50000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4000 - loss: 1.0684 - val_accuracy: 0.5000 - val_loss: 0.6416
# Epoch 7/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4903 - loss: 1.0221
# Epoch 7: val_accuracy improved from 0.50000 to 0.51429, saving model to ./ct_cnn_best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 249s 2s/step - accuracy: 0.4904 - loss: 1.0219 - val_accuracy: 0.5143 - val_loss: 0.9771
# Epoch 8/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 7:59 4s/step - accuracy: 0.6000 - loss: 0.7057
# Epoch 8: val_accuracy did not improve from 0.51429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.6000 - loss: 0.7057 - val_accuracy: 0.0000e+00 - val_loss: 1.3945
# Epoch 9/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4933 - loss: 0.9888
# Epoch 9: val_accuracy did not improve from 0.51429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 237s 2s/step - accuracy: 0.4935 - loss: 0.9889 - val_accuracy: 0.4857 - val_loss: 1.0047
# Epoch 10/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 4:09 2s/step - accuracy: 0.6000 - loss: 0.9041
# Epoch 10: val_accuracy did not improve from 0.51429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6000 - loss: 0.9041 - val_accuracy: 0.5000 - val_loss: 0.6638
# Epoch 11/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5832 - loss: 0.9415
# Epoch 11: val_accuracy did not improve from 0.51429
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 234s 2s/step - accuracy: 0.5830 - loss: 0.9417 - val_accuracy: 0.4857 - val_loss: 1.0145
# Epoch 12/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 3:40 2s/step - accuracy: 0.6000 - loss: 0.6871
# Epoch 12: val_accuracy improved from 0.51429 to 1.00000, saving model to ./ct_cnn_best_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.6000 - loss: 0.6871 - val_accuracy: 1.0000 - val_loss: 0.2126
# Epoch 13/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5818 - loss: 0.9080
# Epoch 13: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 233s 2s/step - accuracy: 0.5818 - loss: 0.9081 - val_accuracy: 0.4429 - val_loss: 0.9726
# Epoch 14/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 3:50 2s/step - accuracy: 0.4000 - loss: 1.1517
# Epoch 14: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4000 - loss: 1.1517 - val_accuracy: 0.5000 - val_loss: 0.9243
# Epoch 15/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5667 - loss: 0.8993
# Epoch 15: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 232s 2s/step - accuracy: 0.5666 - loss: 0.8994 - val_accuracy: 0.5143 - val_loss: 0.9463
# Epoch 16/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 3:39 2s/step - accuracy: 0.6000 - loss: 0.9088
# Epoch 16: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6000 - loss: 0.9088 - val_accuracy: 0.5000 - val_loss: 0.9573
# Epoch 17/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5628 - loss: 0.9264
# Epoch 17: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 234s 2s/step - accuracy: 0.5630 - loss: 0.9262 - val_accuracy: 0.5000 - val_loss: 1.0082
# Epoch 18/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 3:42 2s/step - accuracy: 0.6000 - loss: 0.7523
# Epoch 18: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6000 - loss: 0.7523 - val_accuracy: 0.5000 - val_loss: 0.7553
# Epoch 19/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6242 - loss: 0.8978
# Epoch 19: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.6239 - loss: 0.8983 - val_accuracy: 0.4714 - val_loss: 1.0380
# Epoch 20/20
#   1/122 ━━━━━━━━━━━━━━━━━━━━ 4:31 2s/step - accuracy: 0.8000 - loss: 0.6966
# Epoch 20: val_accuracy did not improve from 1.00000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8000 - loss: 0.6966 - val_accuracy: 1.0000 - val_loss: 0.7228

# %%
# Loading the Best Fit Model 
model = load_model("./ct_cnn_best_model.keras")

# %%
# Checking the Accuracy of the Model 
accuracy_cnn = model.evaluate(test_data)[1] 
print(f"The accuracy of the model is = {accuracy_cnn*100} %")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 383ms/step - accuracy: 0.5433 - loss: 0.8942
# The accuracy of the model is = 55.23809790611267 %

# %%
cnn.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Plot model performance
acc = cnn.history['accuracy']
val_acc = cnn.history['val_accuracy']
loss = cnn.history['loss']
val_loss = cnn.history['val_loss']
epochs_range = range(1, len(cnn.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

plt.tight_layout()
plt.show()
